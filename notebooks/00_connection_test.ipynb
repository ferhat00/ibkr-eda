# %% [markdown]
# # IBKR Connection Test
#
# Verify that IB Gateway is running and connected.
#
# **Prerequisites:**
# 1. Start IB Gateway (`C:\Jts\ibgateway\1044\ibgateway.exe`)
# 2. Log in with your IBKR credentials
# 3. Ensure API connections are enabled (Configure → Settings → API → Enable ActiveX and Socket Clients)
# 4. Default port: 4002 (paper trading) or 4001 (live)

# %%
from ibkr_eda import IBKR

ib = await IBKR.create_async()  # async connect for Jupyter / Python 3.14+

# %% [markdown]
# ## Connection Status

# %%
ib.status()
# Out:
# {'connected': True, 'accounts': ['U13570585', 'U14593335', 'U14601303']}

# %% [markdown]
# ## Accounts

# %%
ib.accounts.list_accounts()
# Out:
# [{'accountId': 'U13570585'},
#  {'accountId': 'U14593335'},
#  {'accountId': 'U14601303'}]

# %% [markdown]
# ## Account Summary

# %% [markdown]
# ## Positions

# %%
positions = ib.positions.get(account_id="U14593335")
positions
# Out:
#     contract_id description asset_class  quantity    avg_cost currency ticker  \
# 0      41015924        UGAS         STK      50.0   61.300000      USD   UGAS
# 1      41015921        CRUD         STK     200.0   11.070000      USD   CRUD
# 2     166090175        BABA         STK      20.0  152.965020      USD   BABA
# 3     151484752        NNND         STK      25.0   68.630000      EUR   NNND
# 4      88819736        NBIS         STK      30.0   75.952243      USD   NBIS
# 5     326398514          BE         STK      20.0  139.245000      USD     BE
# 6     500073396        OKLO         STK      45.0   70.732222      USD   OKLO
# 7          8823         KGC         STK     230.0   24.278749      USD    KGC
# 8       4816190        PAAS         STK      40.0   57.455000      USD   PAAS
# 9      26763006         ARG         STK     500.0    4.930000      CAD    ARG
# 10    815043082        PMET         STK     400.0    2.200000      CAD   PMET
# 11        13977         XOM         STK      20.0  146.840000      USD    XOM
# 12      3691937        AMZN         STK      55.0  220.970922      USD   AMZN
# 13     86656185        SGLN         STK     149.0   56.057258      GBP   SGLN
# 14    756894871         LAR         STK     300.0    1.825035      USD    LAR
# 15       908940        BARC         STK    2000.0    4.323495      GBP   BARC
# 16     35359385        BIDU         STK      20.0  116.230020      USD   BIDU
# 17     71294096         PLS         STK    2494.0    2.477426      AUD    PLS
# 18     88383131         RR.         STK     350.0    4.936044      GBP    RR.
# 19     44202618         LTR         STK    1400.0    0.781071      AUD    LTR
# 20    323608988        1810         STK     400.0   39.466122      HKD   1810
# 21         7890         HAL         STK     160.0   32.883900      USD    HAL
# 22    237880551         DRO         STK    1000.0    2.186000      AUD    DRO
# 23    168391375         LEU         STK      18.0  206.293344      USD    LEU
# 24    501094693         LKY         STK    2000.0    0.613000      AUD    LKY
# 25    657517509         LAC         STK     400.0    3.053793      USD    LAC
# 26    771313676         ACG         STK      50.0   17.460000      GBP    ACG
# 27    208813719       GOOGL         STK      34.0  298.666253      USD  GOOGL
#
#    exchange account_id
# 0       LSE  U14593335
# 1       LSE  U14593335
# 2      NYSE  U14593335
# 3      SWB2  U14593335
# 4    NASDAQ  U14593335
# 5      NYSE  U14593335
# 6      NYSE  U14593335
# 7      NYSE  U14593335
# 8      NYSE  U14593335
# 9       TSE  U14593335
# 10      TSE  U14593335
# 11     NYSE  U14593335
# 12   NASDAQ  U14593335
# 13   LSEETF  U14593335
# 14     NYSE  U14593335
# 15      LSE  U14593335
# 16   NASDAQ  U14593335
# 17      ASX  U14593335
# 18      LSE  U14593335
# 19      ASX  U14593335
# 20     SEHK  U14593335
# 21     NYSE  U14593335
# 22      ASX  U14593335
# 23     NYSE  U14593335
# 24      ASX  U14593335
# 25     NYSE  U14593335
# 26      LSE  U14593335
# 27   NASDAQ  U14593335

# %% [markdown]
# ## Recent Trades

# %%
await ib.executions.get_async(account_id="U14593335", start_date="2025-01-01", end_date="2026-03-02")
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Contract Search (example: AAPL)

# %%
await ib.contract_search.search_async("AAPL")
# Out:
#         conid    symbol secType primaryExchange currency  \
# 0      265598      AAPL     STK          NASDAQ      USD
# 1    38708077      AAPL     STK            MEXI      MXN
# 2   273982664      AAPL     STK             EBS      CHF
# 3   532640894      AAPL     STK             TSE      CAD
# 4          -1              BOND
# 5   242506861   AAPLUSD     STK             EBS      USD
# 6          -1              BOND
# 7          -1              BOND
# 8    86792725     AVSPY     IND          NASDAQ      USD
# 9   290656768  NY2LAAPL     IND            NYSE      USD
# 10  578561419      AAPU     STK          NASDAQ      USD
# 11  625840793      APLY     STK            ARCA      USD
# 12  578561458      AAPB     STK          NASDAQ      USD
# 13  762285103      AAPW     STK            BATS      USD
# 14  578561422      AAPD     STK          NASDAQ      USD
# 15  742759295      AAPY     STK            BATS      USD
# 16  789278751      AAPU     STK             TSE      CAD
#
#           derivativeSecTypes
# 0   CFD, OPT, IOPT, WAR, BAG
# 1
# 2
# 3                   OPT, BAG
# 4
# 5
# 6
# 7
# 8
# 9
# 10                  OPT, BAG
# 11                  OPT, BAG
# 12                  OPT, BAG
# 13                  OPT, BAG
# 14                  OPT, BAG
# 15                  OPT, BAG
# 16

# %% [markdown]
# ## Historical Data (example: AAPL, conid=265598)

# %%
history = await ib.history.get_async(conid=265598, period="1m", bar="1d")
history
# Out:
#     timestamp    open    high     low   close      volume
# 0  2026-02-02  260.02  270.49  259.20  270.01  39655663.0
# 1  2026-02-03  269.20  271.88  267.61  269.48  33474713.0
# 2  2026-02-04  272.29  278.95  272.28  276.49  48895823.0
# 3  2026-02-05  278.13  279.50  273.23  275.91  28324121.0
# 4  2026-02-06  277.18  280.91  276.92  278.12  28786690.0
# 5  2026-02-09  277.87  278.20  271.70  274.62  22652888.0
# 6  2026-02-10  274.88  275.37  272.94  273.68  14559246.0
# 7  2026-02-11  274.68  280.18  274.45  275.50  27053330.0
# 8  2026-02-12  275.59  275.72  260.18  261.73  40657148.0
# 9  2026-02-13  261.95  262.23  255.45  255.78  28192429.0
# 10 2026-02-17  257.90  266.29  255.54  263.88  28884358.0
# 11 2026-02-18  263.53  266.82  262.45  264.35  17165724.0
# 12 2026-02-19  262.51  264.48  260.05  260.58  14766272.0
# 13 2026-02-20  258.97  264.75  258.16  264.58  20707070.0
# 14 2026-02-23  263.49  269.43  263.38  266.18  20278380.0
# 15 2026-02-24  267.99  274.89  267.71  272.14  23327759.0
# 16 2026-02-25  271.73  274.94  271.05  274.23  15560865.0
# 17 2026-02-26  274.88  276.11  270.79  272.95  15231491.0
# 18 2026-02-27  272.77  272.81  262.89  264.18  26235914.0
# 19 2026-03-02  262.46  266.53  260.20  264.72  18287591.0

# %% [markdown]
# ## Asset Allocation

# %%
allocation = ib.accounts.get_allocation(account_id="U14593335")
for category, df in allocation.items():
    print(f"\n--- {category} ---")
    display(df)
# Out:
# --- assetClass ---
#   name direction  weight
# 0  STK      long     1.0

# %% [markdown]
# ## Disconnect

# %%
ib.disconnect()
